# %%
3+5
# Out:
# 8

# %%
3-4
# Out:
# -1

# %%
3/4
# Out:
# 0.75

# %%
3*5
# Out:
# 15

# %%
3*'String'
# Out:
# 'StringStringString'

# %%
9**2
# Out:
# 81

# %%
# Out:
# 'strstrstrstrstrstrstrstrstr'

# %%
#check the data type

# %%
type(1)
# Out:
# int

# %%
print(type(1))
# Out:
# <class 'int'>

# %%
type(2.3)
# Out:
# float

# %%
type(111111177278911383321)
# Out:
# int

# %%
type(111111177123456789087654321345678213456278911383321)
# Out:
# int

# %%
type(111111177123456789087654321345678213456278911383321.111111177123456789087654321345678213456278911383321)
# Out:
# float

# %%
type("vjdsmv")
# Out:
# str

# %%
type([])
# Out:
# list

# %%
type({})
# Out:
# dict

# %%
"casjxk"
# Out:
# 'casjxk'

# %%
'casjxk'
# Out:
# 'casjxk'

# %%
'''casjxk'''
# Out:
# 'casjxk'

# %%
'''
casjxk
aaa
'''
# Out:
# '\ncasjxk\naaa\n'

# %%
#variables

# %%
a =10
print(a)
type(a)
# Out:
# 10
# int

# %%
a ="hello"
print(a)
type(a)
# Out:
# hello
# str

# %%
print((3+4)/(3*7)) #BODMAS
# Out:
# 0.3333333333333333

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("hello")
# Out:
# hello

# %%
f_name = "rahul"
l_name = "patel"

# %%
print("My first name is {} and last name is {}".format(f_name,l_name))
# Out:
# My first name is rahul and last name is patel

# %%
print("My first name is {} and last name is {}".format(l_name, f_name))
# Out:
# My first name is patel and last name is rahul

# %%
print("My first name is {first} and last name is {last}".format(last=l_name, first=f_name))
# Out:
# My first name is rahul and last name is patel

# %%
len("ssjsj")
# Out:
# 5

# %%
len(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-259a5f0bada9> in <module>
# ----> 1 len(100)
#
# TypeError: object of type 'int' has no len()

# %%
a = input("enter value")
# Out:
# enter value10

# %%
type(a)
# Out:
# str

# %%
a = int(input("enter value"))
type(a)
# Out:
# enter value10
# int

# %%
a = u'asss'
type(a)
# Out:
# str

# %%
a = b'asss'
type(a)
# Out:
# bytes

# %% [markdown]
# # print() function
#
# ![image.png](attachment:image.png)

# %%
print("add","awuyahsbw" ,"qw")
# Out:
# add awuyahsbw qw

# %%
print("add","awuyahsbw" ,"qw",sep="SSS")
# Out:
# addSSSawuyahsbwSSSqw

# %%
print("add","awuyahsbw" ,"qw",sep="SSS", end="PPP")
# Out:
# addSSSawuyahsbwSSSqwPPP

# %%
a = 10
b = a
print(a,b,id(a),id(b))
b = 10
print(a,b,id(a),id(b))
b = 20
print(a,b,id(a),id(b))
c = 10
print(a,c,id(a),id(c))
# Out:
# 10 10 4453492336 4453492336
# 10 10 4453492336 4453492336
# 10 20 4453492336 4453492656
# 10 10 4453492336 4453492336

# %% [markdown]
# ### Multiple Assignment

# %%
x=y=z=10    
print(x)    
print(y)    
print(z)
# Out:
# 10
# 10
# 10

# %%
a,b,c=5,10,15    
print(a,b,c)
# Out:
# 5 10 15

# %%
a,b,c=5,10,15,20   
print(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-7389f71d7ccb> in <module>
# ----> 1 a,b,c=5,10,15,20
#       2 print(a,b,c)
#
# ValueError: too many values to unpack (expected 3)

# %%
a,b,c,d =5,10,15  
print(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-54b17c1587a8> in <module>
# ----> 1 a,b,c,d =5,10,15
#       2 print(a,b,c)
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %% [markdown]
# # Global Variables

# %%
# Declare a variable and initialize it  
x = 101  
  
# Global variable in function  
def glob():  
    # printing a global variable  
    global x  
    print(x)  
    # modifying a global variable  
    x = 'Hello'  
    print(x)  
  
glob()  
print(x)
# Out:
# 101
# Hello
# Hello

# %%
# Declare a variable and initialize it  
x = 101  
  
# Global variable in function  
def glob():  
    x = 2292
    print(x)
    # printing a global variable  
    global x  
    print(x)  
    # modifying a global variable  
    x = 'Hello'  
    print(x)  
  
glob()  
print(x)
# Out:
#   File "cell_name", line 12
# SyntaxError: name 'x' is used prior to global declaration

# %%
x = 10
print(x)  
del x  
print(x)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-8c815f9c587f> in <module>
#       2 print(x)
#       3 del x
# ----> 4 print(x)
#
# NameError: name 'x' is not defined

# %%
a = 10000000000000000000000000000000000000000000100000000000000000000000000000000000000000001000000000000000000000000000000000000000000010000000000000000000000000000000000000000000  
a = a + 1  
print(type(a))  
print (a)
# Out:
# <class 'int'>
# 10000000000000000000000000000000000000000000100000000000000000000000000000000000000000001000000000000000000000000000000000000000000010000000000000000000000000000000000000000001

# %% [markdown]
# # Python Keywords

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 10  
b = 0  
print('a is dividing by Zero')  
assert b != 0
print(a / b)
# Out:
# a is dividing by Zero
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-80-a00e8edbce48> in <module>
#       2 b = 0
#       3 print('a is dividing by Zero')
# ----> 4 assert b != 0
#       5 print(a / b)
#
# AssertionError:

# %%
a = 10  
b = 0  
print('a is dividing by Zero')  
if b == 0:
    raise Exception("b can not be Zero")
print(a)
# Out:
# a is dividing by Zero
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-83-539a8190f6e2> in <module>
#       3 print('a is dividing by Zero')
#       4 if b == 0:
# ----> 5     raise Exception("b can not be Zero")
#       6 print(a)
#
# Exception: b can not be Zero

# %%
# is - This keyword is used to check if the two-variable refers to the same object
# Note: A mutable data-types do not refer to the same object.

# %%
x = 5  
y = 5  
  
a = []  
b = []  
print(x is y)  
print(a is b)
# Out:
# True
# False

# %% [markdown]
# ### nonlocal
# - The nonlocal is similar to the global and used to work with a variable inside the nested function(function inside a function)

# %%
def outside_function():    
    a = 20     
    def inside_function():    
        nonlocal a    
        a = 30    
        print("Inner function: ",a)    
    inside_function()    
    print("Outer function: ",a)    
outside_function()
# Out:
# Inner function:  30
# Outer function:  30

# %%
def outside_function():    
    a = 20     
    def inside_function():    
        a = 30    
        print("Inner function: ",a)
        def inside_function3():    
            nonlocal a    
            a = 30    
            print("Inner function3: ",a)    
        inside_function3() 
        print("Inner function2: ",a)
    inside_function()    
    print("Outer function: ",a)    
outside_function()
# Out:
# Inner function:  30
# Inner function3:  30
# Inner function2:  30
# Outer function:  20

# %% [markdown]
# ### lamdo
# - used to create the anonymous function in Python

# %%
lamb = lambda x: x**2

# %%
lamb(3)
# Out:
# 9

# %% [markdown]
# ### yield
# - The yield keyword is used with the Python generator. It stops the function's execution and returns value to the caller.

# %%
def fun_Generator():  
  yield 1  
  yield 2  
  yield 3

# %%
for value in fun_Generator():  
  print(value)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### with
# - The with keyword is used in the exception handling.
# - It makes code cleaner and more readable.
# - The advantage of using with, we don't need to call close().

# %%
with open("hello", "w") as file:
    file.write("abcd")

# %%
# !less /Users/admin/Documents/Python-Tutorial/hello
# Out:
# abcd?47h=
# (END)ocuments/Python-Tutorial/hello (END)

# %% [markdown]
# # Python Literals

# %%
'aa\
ddd'
# Out:
# 'aaddd'

# %%
"asd"
# Out:
# 'asd'

# %%
x = 0b10100 #Binary Literals  
y = 100 #Decimal Literal   
z = 0o215 #Octal Literal  
u = 0x12d #Hexadecimal Literal

# %%
print(x,y,z,u)
# Out:
# 20 100 141 301

# %%
#Float Literal  
a = 100.5   
b = 1.5e2  

print(a,b)
# Out:
# 100.5 150.0

# %%
#Complex Literal   
a = 5+3.14j  
print(a)
print(a.real, a.imag)
# Out:
# (5+3.14j)
# 5.0 3.14

# %%
z = (2 == True)  
a = True + 10 
print(z,a)
print(type(a))
b = False + 10 
print(b)
# Out:
# False 11
# <class 'int'>
# 10

# %%
nar = None
print(nar)
# Out:
# None

# %%
for i in [1,2,3,4,5]:   
    if(i==4):  
        pass  
        print("This is pass block",i)  
    print(i)
# Out:
# 1
# 2
# 3
# This is pass block 4
# 4
# 5

# %%
print(r'C://python37') # prints C://python37 as it is written. It is used to specify the raw string
# Out:
# C://python37

# %%
str = "hello"
print("The string str : %s"%(str)) # prints The string str : Hello. It is used to perform string formatting.
# Out:
# The string str : hello

# %%
a = 2
b = 3.4
c = "Hi"
print("%d %f %s"%(a,b,c))
# Out:
# 2 3.400000 Hi

# %%
# Note: The tuple which is created without using parentheses is also known as tuple packing.

T = 10,20,30,40,50  
print(T)
# Out:
# (10, 20, 30, 40, 50)

# %% [markdown]
# Creating a tuple with single element is slightly different.
# We will need to put comma after the element to declare the tuple.

# %%
a = ("sss")
print(type(a))
# Out:
# <class 'str'>

# %%
a = ("sss", )
print(type(a))
# Out:
# <class 'tuple'>
