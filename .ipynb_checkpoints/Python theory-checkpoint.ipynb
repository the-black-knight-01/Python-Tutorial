# %% [markdown]
# invented by **Guido van Rossum**
#
#
# # What is Python
# - simple
# - general purpose
# - object-oriented programming language.
# - interpreted scripting language
# - high level
# - dynamic typing
#
# #### https://www.javatpoint.com/python-tutorial

# %% [markdown]
# ### high level
# - https://www.geeksforgeeks.org/difference-between-high-level-and-low-level-languages/
# - ![image.png](attachment:image.png)

# %% [markdown]
# ### dynamic typing
# -  ideal language for scripting
# - rapid application development

# %% [markdown]
# ### general purpose
# - web, enterprise, 3D CAD, ML, Desktop app

# %% [markdown]
# ## Python2 vs 3
# - https://www.geeksforgeeks.org/important-differences-between-python-2-x-and-python-3-x-with-examples/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Frameworks and Libraries
# - web development (Server-side) - Django, Flask, Pyramid, CherryPy
# - GUIs based applications - Tk, PyGTK, PyQt, PyJs, etc.
# - Machine Learning - TensorFlow, PyTorch, Scikit-learn, Matplotlib, Scipy, etc.
# - Mathematics - Numpy, Pandas, etc.

# %% [markdown]
# # is Python Compiled or Interpreted Language?
# - https://www.youtube.com/watch?v=0BhSWyDEDC4&ab_channel=Telusko
# - https://www.youtube.com/watch?v=vZu-khdQUqI&ab_channel=MySirG.com

# %% [markdown]
# # Is Python an extensible language?
# Python is an Extensible language. We can write us some Python code into C or C++ language and also we can compile that code in C/C++ language
